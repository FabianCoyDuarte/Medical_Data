# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202101.xlsx')
data2 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202102.xlsx')
data3 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202103.xlsx')
data4 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202104.xlsx')
data5 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202105.xlsx')
data6 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202106.xlsx')
data7 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202107.xlsx')
data8 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202108.xlsx')
data9 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202109.xlsx')
data10 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202110.xlsx')
data11 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202111.xlsx')
data12 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202112.xlsx')

# %%
 rotacion_data1 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Rotacion_CruzVerde_800093391_Consumo_Farma_A_202101.xlsx')
rotacion_data2 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Rotacion_CruzVerde_800093391_Consumo_Farma_A_202102.xlsx')
rotacion_data3 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Rotacion_CruzVerde_800093391_Consumo_Farma_A_202103.xlsx')
rotacion_data4 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Rotacion_CruzVerde_800093391_Consumo_Farma_A_202104.xlsx')
rotacion_data5 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Rotacion_CruzVerde_800093391_Consumo_Farma_A_202105.xlsx')
rotacion_data6 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Rotacion_CruzVerde_800093391_Consumo_Farma_A_202106.xlsx')
rotacion_data7 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Rotacion_CruzVerde_800093391_Consumo_Farma_A_202107.xlsx')
rotacion_data8 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Rotacion_CruzVerde_800093391_Consumo_Farma_A_202108.xlsx')
rotacion_data9 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Rotacion_CruzVerde_800093391_Consumo_Farma_A_202109.xlsx')
rotacion_data10 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Rotacion_CruzVerde_800093391_Consumo_Farma_A_202110.xlsx')

# %%
portafolio = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Portafolio Novamed.xlsx')

# %%
data1.head()
# Out:
#                 FECHA DIVISION  CODIGO ORGANIZACION  \
# 0 2021-01-02 06:36:54    FARMA                   27
# 1 2021-01-02 06:36:54    FARMA                   27
# 2 2021-01-02 06:36:54  CONSUMO                   27
# 3 2021-01-02 06:36:54    FARMA                  281
# 4 2021-01-02 06:36:54  CONSUMO                   20
#
#                             ORGANIZACION Regional  Ciudad  \
# 0             27_FARMA_CLINICA_VERSALLES     Cali    CALI
# 1             27_FARMA_CLINICA_VERSALLES     Cali    CALI
# 2             27_FARMA_CLINICA_VERSALLES     Cali    CALI
# 3  281_FARMA_URGENCIAS_CLINICA_VERSALLES     Cali    CALI
# 4               20_FARMA_CLINICA_COUNTRY   Bogota  BOGOTA
#
#                           Direccion  nit_proveedor nombre_proveedor  ARTICULO  \
# 0  Avda 5A Norte No 23N - 63 OF 203      800093391       NOVAMED SA    127113
# 1  Avda 5A Norte No 23N - 63 OF 203      800093391       NOVAMED SA    141425
# ...

# %%
data2.head()
# Out:
#   Regional  CODIGO ORGANIZACION                           ORGANIZACION  \
# 0     Cali                   27             27_FARMA_CLINICA_VERSALLES
# 1     Cali                   27             27_FARMA_CLINICA_VERSALLES
# 2     Cali                  281  281_FARMA_URGENCIAS_CLINICA_VERSALLES
# 3   Bogota                   20               20_FARMA_CLINICA_COUNTRY
# 4   Bogota                   20               20_FARMA_CLINICA_COUNTRY
#
#    ARTICULO                                 DESCRIPCION            EAN  \
# 0    127113   FERBIN 250MG/5ML(5%) JBE INST FCO X 120ML  7703546163224
# 1    141425  PROPANOLOL 40MG TAB INST CAJ X 300 NOVAMED  7703546843003
# 2    127113   FERBIN 250MG/5ML(5%) JBE INST FCO X 120ML  7703546163224
# 3    117849               NUTRIBEN NATAL    TAR X 400GR  7703546722407
# 4    125234                 NUTRIBEN A.R    TAR X 400GR  7703546720007
#
#    Unnamed: 6  Unnamed: 7  CANTIDAD ARTICULO  COSTO TOTAL ARTICULO
# ...

# %%
data1.columns
# Out:
# Index(['FECHA', 'DIVISION', 'CODIGO ORGANIZACION', 'ORGANIZACION', 'Regional',
#        'Ciudad', 'Direccion', 'nit_proveedor', 'nombre_proveedor', 'ARTICULO',
#        'EAN', 'DESCRIPCION', 'FACTOR', 'UDM', 'CANTIDAD ARTICULO',
#        'COSTO TOTAL ARTICULO'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['Regional', 'CODIGO ORGANIZACION', 'ORGANIZACION', 'ARTICULO',
#        'DESCRIPCION', 'EAN', 'Unnamed: 6', 'Unnamed: 7', 'CANTIDAD ARTICULO',
#        'COSTO TOTAL ARTICULO'],
#       dtype='object')

# %%
data3.columns
# Out:
# Index(['FECHA', 'DIVISION', 'CODIGO ORGANIZACION', 'ORGANIZACION', 'Regional',
#        'Ciudad', 'Direccion', 'nit_proveedor', 'nombre_proveedor', 'ARTICULO',
#        'EAN', 'DESCRIPCION', 'FACTOR', 'UDM', 'CANTIDAD ARTICULO',
#        'COSTO TOTAL ARTICULO'],
#       dtype='object')

# %%
data1.columns == data3.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
data4.columns == data3.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
print(data1.shape)
print(data2.shape)
print(data3.shape)
print(data4.shape)
print(data5.shape)
print(data6.shape)
print(data7.shape)
print(data8.shape)
print(data9.shape)
print(data10.shape)
print(data11.shape)
print(data12.shape)
# Out:
# (14940, 16)
# (14589, 10)
# (15159, 16)
# (15088, 16)
# (15389, 16)
# (15789, 10)
# (16364, 10)
# (16517, 10)
# (17287, 16)
# (17817, 16)
# (18778, 16)
# (20067, 16)

# %%
data_16_columns = pd.concat([data1,data3,data4,data5,data9,data10]).reset_index(drop=True)
data_10_colummns = pd.concat([data2,data6,data7,data8]).reset_index(drop=True)
print(data_16_columns.shape)
print(data_10_colummns.shape)
# Out:
# (95680, 16)
# (63259, 10)

# %%
data_10_colummns.drop(['Unnamed: 6', 'Unnamed: 7'], axis=1, inplace=True)
data_10_colummns.isnull().sum()
# Out:
# Regional                0
# CODIGO ORGANIZACION     0
# ORGANIZACION            0
# ARTICULO                0
# DESCRIPCION             0
# EAN                     0
# CANTIDAD ARTICULO       0
# COSTO TOTAL ARTICULO    0
# dtype: int64

# %%
data_16_columns.isnull().sum()
# Out:
# FECHA                   0
# DIVISION                0
# CODIGO ORGANIZACION     0
# ORGANIZACION            0
# Regional                0
# Ciudad                  0
# Direccion               0
# nit_proveedor           0
# nombre_proveedor        0
# ARTICULO                0
# EAN                     0
# DESCRIPCION             0
# FACTOR                  0
# UDM                     0
# CANTIDAD ARTICULO       0
# COSTO TOTAL ARTICULO    0
# dtype: int64

# %%
portafolio['EAN'] = portafolio['COD_EAN13']

# %%
col16 = data_16_columns['EAN'].unique()
col10 = data_10_colummns['EAN'].unique()
y = portafolio['EAN'].unique()
out_portafolio_16 = []
out_portafolio_10 = []
for i in range(len(col16)):
    if col16[i] not in y:
        out_portafolio_16.append(col16[i])

for j in range(len(col10)):
    if col10[j] not in y:
        out_portafolio_10.append(col10[j])

# %%
cod_barras_name_16 = data_16_columns[data_16_columns['EAN'].isin(out_portafolio_16)]

cod_barras_name_10 = data_10_colummns[data_10_colummns['EAN'].isin(out_portafolio_10)]


not_be_16 = pd.DataFrame({'Codigo de barras':cod_barras_name_16['EAN'],'Descripción Producto':cod_barras_name_16['DESCRIPCION']}).reset_index(drop=True)
not_be_10 = pd.DataFrame({'Codigo de barras':cod_barras_name_10['EAN'],'Descripción Producto':cod_barras_name_10['DESCRIPCION']}).reset_index(drop=True)

# %%
not_be_16
# Out:
#       Codigo de barras                               Descripción Producto
# 0        2000101140498           METASPRAY 0.05% SUSP NAS INST FCO X 10ML
# 1        7703546041430  PROMO DOLORSIN FEM PAG3 LLEV4 (20+400)MG CAP  ...
# 2        2000101454885                   LIPOGRAS 120MG CAP INST CAJ X 60
# 3        2000101610083                    ARTRIDOX 50MG CAP INST CAJ X 30
# 4        2000101696131  AIROMED 4MG/SOB GRAN SUSP ORAL INST CAJ X 30SO...
# ...                ...                                                ...
# 6920     7703546701495                        GEL ORAL  CAJ X 21 GELCLAIR
# 6921     2000101261599      ZIPED 10MG/5ML(0.2%) SOL ORAL INST FCO X 90ML
# 6922     2000103842406  AZEFLU (137+50)MCG/DOSIS SUSP NAS INST FCO X 3...
# 6923     2000101140504           METASPRAY 0.05% SUSP NAS INST FCO X 18ML
# 6924     2000101140504           METASPRAY 0.05% SUSP NAS INST FCO X 18ML
#
# [6925 rows x 2 columns]

# %%
output_16 = not_be_16.groupby('Codigo de barras')['Descripción Producto'].unique()
output_10 = not_be_10.groupby('Codigo de barras')['Descripción Producto'].unique()
# output_merge = pd.merge(output_16, output_10, on='Codigo de barras', how='outer')
# output.to_csv(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Not_in_portafolio.csv')

# %%
len(output_10)
# Out:
# 28

# %%
output_merge = output_16.append(output_10)
# Out:
# C:\Users\fcoy\AppData\Local\Temp\ipykernel_21712\1990678565.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   output_merge = output_16.append(output_10)
# 56

# %%
out_data = pd.DataFrame({'Codigo de barras': output_merge.index, 'Descripción Producto': output_merge.values})
product_name = out_data['Descripción Producto']
correct_name = []
for name in product_name:
    correct_name.append(name[0])

out_data['Nombre del producto'] = correct_name
out_data.drop(['Descripción Producto'], axis=1, inplace=True)
final = out_data.groupby('Codigo de barras')['Nombre del producto'].unique()
final.to_csv(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\No_Portafolio_Inventario.csv')

# %%
data2.columns == data8.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
print(rotacion_data1.shape)
print(rotacion_data2.shape)
print(rotacion_data3.shape)
print(rotacion_data4.shape)
print(rotacion_data5.shape)
print(rotacion_data6.shape)
print(rotacion_data7.shape)
print(rotacion_data8.shape)
print(rotacion_data9.shape)
print(rotacion_data10.shape)
# Out:
# (7358, 19)
# (7558, 19)
# (8096, 19)
# (7966, 19)
# (7835, 19)
# (8466, 19)
# (9179, 19)
# (9087, 19)
# (8580, 19)
# (9394, 19)

# %%
data1['nombre_proveedor'].unique()
# Out:
# array(['NOVAMED SA'], dtype=object)

# %%
portafolio.head()
# Out:
#        CANAL      COD_EAN13     CODPRO                       NOMPROD  \
# 0  COMERCIAL  7703546015158  870105150      ACIDRINE 10 mg * 15 TAB.
# 1  COMERCIAL  7703546018029  870108020           ACIDRINE GOTAS 25ml
# 2  COMERCIAL  7703546156004  870109100          ACIDRINE JBE. 100 ml
# 3  COMERCIAL  7703546014076  870104070  ACIDRINE-D JBE FRASCO x 60ml
# 4  COMERCIAL  7703546703116  870101230         ACTIN 120mg x 30 CAP.
#
#               LINEA     MARCA
# 0     RESP. RINITIS  ACIDRINE
# 1     RESP. RINITIS  ACIDRINE
# 2     RESP. RINITIS  ACIDRINE
# 3     RESP. RINITIS  ACIDRINE
# 4  SIS NERVIOSO CEN     ACTIN

# %%
rotation_data = pd.concat([rotacion_data1, rotacion_data2, rotacion_data3, rotacion_data4, rotacion_data5, rotacion_data6, rotacion_data7, rotacion_data8, rotacion_data9, rotacion_data10]).reset_index(drop=True)

# %%
rotation_data.head()
# Out:
#    Periodo División  Codigo Org Inventario             Nombre Org Inventario  \
# 0   202101  CONSUMO                    601   601_CRUZ_VERDE_UNICENTRO BOGOTA
# 1   202101  CONSUMO                    260       260_ CRUZ_VERDE_METRO_PASTO
# 2   202101  CONSUMO                    262    262_ CRUZ_VERDE_JUMBO_HAYUELOS
# 3   202101    FARMA                    718  718_CRUZ_VERDE_SR_MEDICARTE_BUGA
# 4   202101    FARMA                    717      717_CRUZ_VERDE_DEPARTAMENTAL
#
#   Regional             Ciudad  \
# 0   Bogota             BOGOTA
# 1     Cali  SAN JUAN DE PASTO
# 2   Bogota             BOGOTA
# 3     Cali               BUGA
# 4     Cali               CALI
#
#                                            Dirección Actividad Canal  \
# 0      Av. Kra 15 N. 124 - 30 C.C Unicentro Lc. 2-83       COMERCIAL
# 1  Av Panamericana entre Calle 11 y 12, CENTRO CO...       COMERCIAL
# 2                             Carrera 84 No. 26 - 50       COMERCIAL
# ...

# %%
from datetime import datetime, timedelta
import locale
locale.setlocale(locale.LC_ALL, ("es_ES", "UTF-8"))
# Out:
# 'es_ES.UTF-8'

# %%
s = rotation_data['Periodo']
print(s)
# Out:
# 0        202101
# 1        202101
# 2        202101
# 3        202101
# 4        202101
#           ...
# 83514    202110
# 83515    202110
# 83516    202110
# 83517    202110
# 83518    202110
# Name: Periodo, Length: 83519, dtype: int64

# %%
date = []
for i in range(len(s)):
    temp = str(s[i])
    x = datetime(year=int(temp[0:4]), month=int(temp[4:6]), day=1)
    month = x.strftime("%B")
    date.append(month)

# %%
rotation_data['Mes'] = date

# %%
meses = rotation_data['Mes'].unique()
x = rotation_data.groupby(rotation_data['Mes'])['Costo Compra'].sum().reset_index()
x.index = pd.CategoricalIndex(x['Mes'], categories=meses, ordered=True)
x.sort_index().reset_index(drop=True)
# Out:
#           Mes  Costo Compra
# 0       enero  9.127609e+08
# 1     febrero  9.081347e+08
# 2       marzo  1.306908e+09
# 3       abril  1.002566e+09
# 4        mayo  9.591234e+08
# 5       junio  1.025776e+09
# 6       julio  1.450115e+09
# 7      agosto  1.375306e+09
# 8  septiembre  1.221674e+09
# 9     octubre  1.335422e+09

# %%
portafolio['Código de Barras'] = portafolio['COD_EAN13']

# %%
portafolio.columns
# Out:
# Index(['CANAL', 'COD_EAN13', 'CODPRO', 'NOMPROD', 'LINEA', 'MARCA',
#        'Código de Barras'],
#       dtype='object')

# %%
rotation_data.columns
# Out:
# Index(['Periodo', 'División', 'Codigo Org Inventario', 'Nombre Org Inventario',
#        'Regional', 'Ciudad', 'Dirección', 'Actividad Canal', 'Tipo Sucursal',
#        'CLASE_ORG', 'Nit', 'Proveedor', 'Código Producto', 'Código de Barras',
#        'Descripción Producto', 'Factor', 'Presentación', 'Unidades vendidas',
#        'Costo Compra', 'Mes'],
#       dtype='object')

# %%
merge_df = pd.merge(rotation_data, portafolio, on='Código de Barras', how='left')

# %%
len(rotation_data['Código de Barras'].unique())
# Out:
# 225

# %%
len(portafolio['Código de Barras'].unique())
# Out:
# 276

# %%
x = rotation_data['Código de Barras'].unique() 
y = portafolio['Código de Barras'].unique()
in_portafolio = []
for i in range(len(x)):
    if x[i] not in y:
        in_portafolio.append(x[i])

# %%
len(in_portafolio)
# Out:
# 36

# %%
cod_barras_name = rotation_data[rotation_data['Código de Barras'].isin(in_portafolio)]
# cod_barras_name['Código de Barras']
# cod_barras_name['Descripción Producto']

not_be = pd.DataFrame({'Codigo de barras':cod_barras_name['Código de Barras'],'Descripción Producto':cod_barras_name['Descripción Producto']}).reset_index(drop=True)

# %%
output = not_be.groupby('Codigo de barras')['Descripción Producto'].unique()
output.to_csv(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Not_in_portafolio.csv')

# %%
merge_df.head()
# Out:
#    Periodo División  Codigo Org Inventario             Nombre Org Inventario  \
# 0   202101  CONSUMO                    601   601_CRUZ_VERDE_UNICENTRO BOGOTA
# 1   202101  CONSUMO                    260       260_ CRUZ_VERDE_METRO_PASTO
# 2   202101  CONSUMO                    262    262_ CRUZ_VERDE_JUMBO_HAYUELOS
# 3   202101    FARMA                    718  718_CRUZ_VERDE_SR_MEDICARTE_BUGA
# 4   202101    FARMA                    717      717_CRUZ_VERDE_DEPARTAMENTAL
#
#   Regional             Ciudad  \
# 0   Bogota             BOGOTA
# 1     Cali  SAN JUAN DE PASTO
# 2   Bogota             BOGOTA
# 3     Cali               BUGA
# 4     Cali               CALI
#
#                                            Dirección Actividad Canal  \
# 0      Av. Kra 15 N. 124 - 30 C.C Unicentro Lc. 2-83       COMERCIAL
# 1  Av Panamericana entre Calle 11 y 12, CENTRO CO...       COMERCIAL
# 2                             Carrera 84 No. 26 - 50       COMERCIAL
# ...

# %%
merge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100068 entries, 0 to 100067
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Periodo                100068 non-null  int64
#  1   División               100068 non-null  object
#  2   Codigo Org Inventario  100068 non-null  int64
#  3   Nombre Org Inventario  100068 non-null  object
#  4   Regional               100068 non-null  object
#  5   Ciudad                 100068 non-null  object
#  6   Dirección              100068 non-null  object
#  7   Actividad Canal        100068 non-null  object
#  8   Tipo Sucursal          93478 non-null   object
#  9   CLASE_ORG              67564 non-null   object
#  10  Nit                    100068 non-null  int64
#  11  Proveedor              100068 non-null  object
#  12  Código Producto        100068 non-null  int64
#  13  Código de Barras       99614 non-null   object
# ...

# %%
merge_df.isnull().sum()
# Out:
# Periodo                      0
# División                     0
# Codigo Org Inventario        0
# Nombre Org Inventario        0
# Regional                     0
# Ciudad                       0
# Dirección                    0
# Actividad Canal              0
# Tipo Sucursal             6590
# CLASE_ORG                32504
# Nit                          0
# Proveedor                    0
# Código Producto              0
# Código de Barras           454
# Descripción Producto         0
# Factor                       0
# Presentación                 0
# Unidades vendidas            0
# Costo Compra                 0
# Mes                          0
# CANAL                    10416
# COD_EAN13                10416
# CODPRO                   10416
# NOMPROD                  10416
# LINEA                    10416
# MARCA                    10416
# dtype: int64

# %%
rotation_data.isnull().sum()
# Out:
# Periodo                      0
# División                     0
# Codigo Org Inventario        0
# Nombre Org Inventario        0
# Regional                     0
# Ciudad                       0
# Dirección                    0
# Actividad Canal              0
# Tipo Sucursal             5584
# CLASE_ORG                27807
# Nit                          0
# Proveedor                    0
# Código Producto              0
# Código de Barras           454
# Descripción Producto         0
# Factor                       0
# Presentación                 0
# Unidades vendidas            0
# Costo Compra                 0
# Mes                          0
# dtype: int64

# %%
rotacion_data1['CLASE_ORG'].unique()
# Out:
# array(['A', 'D', nan, 'E', 'B', 'E+H', 'D+H', 'C', 'C+H', 'B+H'],
#       dtype=object)

# %%
rotacion_data1[rotacion_data1['Tipo Sucursal'].isnull()]
# Out:
#       Periodo División  Codigo Org Inventario  \
# 13     202101    FARMA                    101
# 14     202101  CONSUMO                    101
# 20     202101    FARMA                    312
# 24     202101    FARMA                    113
# 28     202101  CONSUMO                    307
# ...       ...      ...                    ...
# 7310   202101    FARMA                    312
# 7311   202101  CONSUMO                    101
# 7322   202101    FARMA                    308
# 7353   202101    FARMA                    471
# 7355   202101    FARMA                    312
#
#                      Nombre Org Inventario  Regional        Ciudad  \
# 13    101_CRUZ _VERDE _DOMICILIOS _TOBERIN    Bogota        BOGOTA
# 14    101_CRUZ _VERDE _DOMICILIOS _TOBERIN    Bogota        BOGOTA
# 20              312_CRUZ_VERDE_JUMBO_YOPAL    Bogota         YOPAL
# 24                113_CRUZ_VERDE_SAN_DIEGO  Medellin      MEDELLIN
# 28                  307_CRUZ_VERDE_USAQUEN    Bogota        BOGOTA
# ...

# %%
merge_df[merge_df['NOMPROD'].isnull()]
# Out:
#         Periodo División  Codigo Org Inventario  \
# 2        202101  CONSUMO                    262
# 3        202101    FARMA                    718
# 19       202101  CONSUMO                    147
# 23       202101  CONSUMO                    134
# 31       202101  CONSUMO                    307
# ...         ...      ...                    ...
# 99892    202110  CONSUMO                    125
# 99968    202110  CONSUMO                    154
# 99973    202110  CONSUMO                    872
# 100017   202110    FARMA                    351
# 100042   202110  CONSUMO                    836
#
#                                     Nombre Org Inventario        Regional  \
# 2                          262_ CRUZ_VERDE_JUMBO_HAYUELOS          Bogota
# 3                        718_CRUZ_VERDE_SR_MEDICARTE_BUGA            Cali
# 19                                  147_CRUZ_VERDE_INNOVO          Bogota
# 23                           134_CRUZ_VERDE_VILLAVICENCIO          Bogota
# ...

# %%
rotacion_data2[rotacion_data2['Código de Barras'].isnull()]['Descripción Producto'].unique()
# Out:
# array(['IRTAL 5MG TAB REC  CAJ X 28'], dtype=object)

# %%
merge_df[merge_df['Código de Barras'].isnull()]['Descripción Producto'].unique()
# Out:
# array(['IRTAL 5MG TAB REC  CAJ X 28'], dtype=object)

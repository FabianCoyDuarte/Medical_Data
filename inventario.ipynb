# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import locale
locale.setlocale(locale.LC_ALL, ("es_ES", "UTF-8"))
# Out:
# 'es_ES.UTF-8'

# %%
Inventario_data1 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202101.xlsx')
Inventario_data2 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202102.xlsx')
Inventario_data3 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202103.xlsx')
Inventario_data4 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202104.xlsx')
Inventario_data5 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202105.xlsx')
Inventario_data6 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202106.xlsx')
Inventario_data7 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202107.xlsx')
Inventario_data8 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202108.xlsx')
Inventario_data9 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202109.xlsx')
Inventario_data10 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202110.xlsx')
Inventario_data11 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202111.xlsx')
Inventario_data12 = pd.read_excel(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Data Original\Inventario_CruzVerde_800093391_Consumo_Farma_A_202112.xlsx')

# %%
print(Inventario_data1.shape)
print(Inventario_data2.shape)
print(Inventario_data3.shape)
print(Inventario_data4.shape)
print(Inventario_data5.shape)
print(Inventario_data6.shape)
print(Inventario_data7.shape)
print(Inventario_data8.shape)
print(Inventario_data9.shape)
print(Inventario_data10.shape)
print(Inventario_data11.shape)
print(Inventario_data12.shape)
# Out:
# (14940, 16)
# (14589, 16)
# (15159, 16)
# (15088, 16)
# (15389, 16)
# (15789, 16)
# (16364, 11)
# (16517, 16)
# (17287, 16)
# (17817, 16)
# (18778, 16)
# (20067, 16)

# %%
def same_shape_inventario(df):
    order_columns = ['FECHA', 'DIVISION', 'CODIGO ORGANIZACION', 'ORGANIZACION', 'Regional', 'Ciudad', 'Direccion', 'nit_proveedor', 'nombre_proveedor', 'ARTICULO',
       'EAN', 'DESCRIPCION', 'FACTOR', 'UDM', 'CANTIDAD ARTICULO', 'COSTO TOTAL ARTICULO']
    if len(df.columns) < 16:
        Columns = df.columns
        for name in Columns:
            separate_name = name.split(' ')
            if separate_name[0] == 'Unnamed:':
                df.drop(name, axis=1, inplace=True)
        new_columns = df.columns
        for exist_column in range(len(order_columns)):
            if order_columns[exist_column] in new_columns:
                pass
            else:
                df[order_columns[exist_column]] = 'NO ASIGNADO'

    Output = df.reindex(columns=order_columns)
    return Output

# %%
Inventario_data1 = same_shape_inventario(Inventario_data1)
Inventario_data2 = same_shape_inventario(Inventario_data2)
Inventario_data3 = same_shape_inventario(Inventario_data3)
Inventario_data4 = same_shape_inventario(Inventario_data4)
Inventario_data5 = same_shape_inventario(Inventario_data5)
Inventario_data6 = same_shape_inventario(Inventario_data6)
Inventario_data7 = same_shape_inventario(Inventario_data7)
Inventario_data8 = same_shape_inventario(Inventario_data8)
Inventario_data9 = same_shape_inventario(Inventario_data9)
Inventario_data10 = same_shape_inventario(Inventario_data10)
Inventario_data11 = same_shape_inventario(Inventario_data11)
Inventario_data12 = same_shape_inventario(Inventario_data12)

# %%
print(Inventario_data1.shape)
print(Inventario_data2.shape)
print(Inventario_data3.shape)
print(Inventario_data4.shape)
print(Inventario_data5.shape)
print(Inventario_data6.shape)
print(Inventario_data7.shape)
print(Inventario_data8.shape)
print(Inventario_data9.shape)
print(Inventario_data10.shape)
print(Inventario_data11.shape)
print(Inventario_data12.shape)
# Out:
# (14940, 16)
# (14589, 16)
# (15159, 16)
# (15088, 16)
# (15389, 16)
# (15789, 16)
# (16364, 16)
# (16517, 16)
# (17287, 16)
# (17817, 16)
# (18778, 16)
# (20067, 16)

# %%
Inventario_data1.shape[0] + Inventario_data2.shape[0] + Inventario_data3.shape[0] + Inventario_data4.shape[0] + Inventario_data5.shape[0] + Inventario_data6.shape[0] + Inventario_data7.shape[0] + Inventario_data8.shape[0] + Inventario_data9.shape[0] + Inventario_data10.shape[0] + Inventario_data11.shape[0] + Inventario_data12.shape[0]
# Out:
# 197784

# %%
Inventario_data = pd.concat([Inventario_data1, Inventario_data2, Inventario_data3, Inventario_data4, Inventario_data5, Inventario_data6, Inventario_data7, Inventario_data8,
                                Inventario_data9, Inventario_data10, Inventario_data11, Inventario_data12]).reset_index(drop=True)

# %%
Inventario_data.head()
# Out:
#                 FECHA DIVISION  CODIGO ORGANIZACION  \
# 0 2021-01-02 06:36:54    FARMA                   27
# 1 2021-01-02 06:36:54    FARMA                   27
# 2 2021-01-02 06:36:54  CONSUMO                   27
# 3 2021-01-02 06:36:54    FARMA                  281
# 4 2021-01-02 06:36:54  CONSUMO                   20
#
#                             ORGANIZACION Regional  Ciudad  \
# 0             27_FARMA_CLINICA_VERSALLES     Cali    CALI
# 1             27_FARMA_CLINICA_VERSALLES     Cali    CALI
# 2             27_FARMA_CLINICA_VERSALLES     Cali    CALI
# 3  281_FARMA_URGENCIAS_CLINICA_VERSALLES     Cali    CALI
# 4               20_FARMA_CLINICA_COUNTRY   Bogota  BOGOTA
#
#                           Direccion nit_proveedor nombre_proveedor  ARTICULO  \
# 0  Avda 5A Norte No 23N - 63 OF 203     800093391       NOVAMED SA    127113
# 1  Avda 5A Norte No 23N - 63 OF 203     800093391       NOVAMED SA    141425
# ...

# %%
def EXTRAER_MES(df,columna_fecha,columna_precio):
    """
    Función que permite obtener el mes de una dataframe
    """
    columns = df.columns
    date_month = []
    date_year = []
    numeric_month = []
    s = df[columna_fecha]
    for i in range(len(s)):
        transform_date = len(str(s[i]))
        # print(transform_date)
        if transform_date == 19:
            # date.append(s[i])
            temp = str(s[i])
            x = datetime(year=int(temp[0:4]), month=int(temp[8:10]), day=1)
            date_year.append(int(x.strftime('%Y')))
            numeric_month.append(int(x.strftime("%m")))
            month = x.strftime("%B")
            date_month.append(month)
        elif transform_date == 26:
            temp = str(s[i])
            x = datetime(year=int(temp[0:4]), month=int(temp[8:10]), day=1)
            date_year.append(int(x.strftime('%Y')))
            numeric_month.append(int(x.strftime("%m")))
            month = x.strftime("%B")
            date_month.append(month)
        elif transform_date == 'NO ASIGNADO':
            date_year.append('NO ASIGNADO')
            date_month.append(s[i])
            numeric_month.append('NO ASIGNADO')
        else:
            temp = str(s[i])
            x = datetime(year=int(temp[0:4]), month=int(temp[4:6]), day=1)
            date_year.append(int(x.strftime('%Y')))
            numeric_month.append(int(x.strftime("%m")))
            month = x.strftime("%B")
            date_month.append(month)


    df['Mes Numerico'] = numeric_month
    df['Año'] = date_year

    if 'Mes' in columns:
        df['MONTH'] = date_month
        x = df.groupby(['MONTH','Mes Numerico','Año'])[columna_precio].sum().reset_index()
        final = x.sort_values(by=['Año','Mes Numerico'], ascending=True).reset_index(drop=True).drop(columns=['Mes Numerico'])
        # final = x.sort_values('Mes Numerico', ascending=True).reset_index(drop=True).drop(columns=['Mes Numerico'])
    else:
        df['Mes'] = date_month
        x = df.groupby(['Mes','Mes Numerico','Año'])[columna_precio].sum().reset_index()
        final = x.sort_values(by=['Año','Mes Numerico'], ascending=True).reset_index(drop=True).drop(columns=['Mes Numerico'])


    return final, df

# %%
report, df_invent_complete = EXTRAER_MES(Inventario_data,'FECHA','COSTO TOTAL ARTICULO')

# %%
report
# Out:
#          MONTH   Año  COSTO TOTAL ARTICULO
# 0      febrero  2021          2.093121e+09
# 1        marzo  2021          2.281940e+09
# 2        abril  2021          2.281051e+09
# 3         mayo  2021          2.159640e+09
# 4        junio  2021          2.238166e+09
# 5        julio  2021          2.402963e+09
# 6       agosto  2021          2.592465e+09
# 7   septiembre  2021          2.712599e+09
# 8      octubre  2021          2.879030e+09
# 9    noviembre  2021          3.120578e+09
# 10   diciembre  2021          3.188251e+09
# 11       enero  2022          3.500618e+09

# %%
df_invent_complete.columns
# Out:
# Index(['FECHA', 'DIVISION', 'CODIGO ORGANIZACION', 'ORGANIZACION', 'Regional',
#        'Ciudad', 'Direccion', 'nit_proveedor', 'nombre_proveedor', 'ARTICULO',
#        'EAN', 'DESCRIPCION', 'FACTOR', 'UDM', 'CANTIDAD ARTICULO',
#        'COSTO TOTAL ARTICULO', 'Mes Numerico', 'Mes', 'Año', 'MONTH'],
#       dtype='object')

# %%
regionales_inventario= df_invent_complete['Regional'].unique()
print(regionales_inventario)
# regionales_inventario = regionales_inventario.sort()
# print(regionales_inventario)
# Out:
# ['Cali' 'Bogota' 'Bucaramanga' 'Medellin' 'Costa' 'POR DEFINIR'
#  'Tolima - Huila' 'Bogotá D.C.' 'Antioquia' 'Valle' 'Santander'
#  'Centro Oriente' 'Eje Cafetero']

# %%
names_inventario = df_invent_complete.sort_values(by=['Regional'], ascending=True)
names_inventario
# Out:
#                      FECHA DIVISION  CODIGO ORGANIZACION  \
# 139629 2021-03-10 19:01:07    FARMA                  680
# 172713 2021-01-12 04:58:10    FARMA                  520
# 188551 2022-01-01 04:59:38    FARMA                  944
# 172718 2021-01-12 04:58:10  CONSUMO                  199
# 128987 2021-03-10 19:01:07    FARMA                  672
# ...                    ...      ...                  ...
# 165320 2021-01-12 04:58:10    FARMA                  816
# 165319 2021-01-12 04:58:10    FARMA                  894
# 165316 2021-01-12 04:58:10    FARMA                  715
# 190301 2022-01-01 04:59:38    FARMA                  642
# 165657 2021-01-12 04:58:10    FARMA                  714
#
#                                      ORGANIZACION   Regional    Ciudad  \
# 139629               680_CRUZ_VERDE_PREMIUM PLAZA  Antioquia  MEDELLIN
# 172713                  520_CRUZ_VERDE_ EL TESORO  Antioquia  MEDELLIN
# ...

# %%
names_inventario[names_inventario['Regional Correcta'] == 'Antioquia']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\farma\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\.conda\envs\farma\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\.conda\envs\farma\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Regional Correcta'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
int(entero) for entero in report['COSTO TOTAL ARTICULO'])

# %%
def uniform_regions(df, Nombre_Columna_con_Regiones):
    uniform_regions = []
    for reg in range(len(df[Nombre_Columna_con_Regiones])):
         if df[Nombre_Columna_con_Regiones][reg] == 'Bogota':
             uniform_regions.append('Bogota D.C.')
         elif df[Nombre_Columna_con_Regiones][reg] == 'Cali':
             uniform_regions.append('Cali')
         elif df[Nombre_Columna_con_Regiones][reg] == 'Costa':
             uniform_regions.append('Costa')
         elif df[Nombre_Columna_con_Regiones][reg] == 'Medellin':
             uniform_regions.append('Medellin')
         elif df[Nombre_Columna_con_Regiones][reg] == 'Bucaramanga':
             uniform_regions.append('Bucaramanga')
         elif df[Nombre_Columna_con_Regiones][reg] == 'Bogotá D.C.':
             uniform_regions.append('Bogota D.C.')
         elif df[Nombre_Columna_con_Regiones][reg] == 'Antioquia':
             uniform_regions.append('Antioquia')
         elif df[Nombre_Columna_con_Regiones][reg] == 'Santander':
             uniform_regions.append('Santander')
         elif df[Nombre_Columna_con_Regiones][reg] == 'Valle':
             uniform_regions.append('Valle')
         elif df[Nombre_Columna_con_Regiones][reg] == 'Eje Cafetero':
             uniform_regions.append('Eje Cafetero')
         elif df[Nombre_Columna_con_Regiones][reg] == 'Centro Oriente':
             uniform_regions.append('Centro Oriente')
         elif df[Nombre_Columna_con_Regiones][reg] == 'Tolima - Huila':
             uniform_regions.append('Tolima - Huila')
         else:
             uniform_regions.append(df['Regional'][reg])
    df['Regional Correcta'] = uniform_regions
    return df

# %%
Uniform_Names_Inventario = uniform_regions(df_invent_complete,'Regional')

# %%
Uniform_Names_Inventario['Regional Correcta'].unique()
# Out:
# array(['Cali', 'Bogota D.C.', 'Bucaramanga', 'Medellin', 'Costa',
#        'POR DEFINIR', 'Tolima - Huila', 'Antioquia', 'Valle', 'Santander',
#        'Centro Oriente', 'Eje Cafetero'], dtype=object)

# %%
df_inventario_completo = pd.read_csv(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Reporte_Merge_Rotacion_Portafolio.csv')
# Out:
# C:\Users\fcoy\AppData\Local\Temp\ipykernel_2600\3185328810.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_inventario_completo = pd.read_csv(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Reporte_Merge_Rotacion_Portafolio.csv')

# %%
df_inventario_completo.columns
# Out:
# Index(['Unnamed: 0', 'Periodo', 'División', 'Codigo Org Inventario',
#        'Nombre Org Inventario', 'Regional', 'Ciudad', 'Dirección',
#        'Actividad Canal', 'Tipo Sucursal', 'CLASE_ORG', 'Nit', 'Proveedor',
#        'Código Producto', 'Código de Barras', 'Descripción Producto', 'Factor',
#        'Presentación', 'Unidades vendidas', 'Costo Compra',
#        'Regional Correcta', 'Mes Numerico', 'Mes', 'CANAL', 'COD_EAN13',
#        'CODPRO', 'NOMPROD', 'LINEA', 'MARCA', 'EAN'],
#       dtype='object')

# %%
regional_behaviour = df_inventario_completo.groupby(['NOMPROD','Regional Correcta', 'Mes','Mes Numerico'])['COSTO TOTAL ARTICULO'].sum().reset_index()

# %%
x = regional_behaviour[regional_behaviour['NOMPROD']== 'ACIDRINE 10 mg * 15 TAB.'].groupby(['Mes','Mes Numerico'])['COSTO TOTAL ARTICULO'].sum().reset_index()
x.sort_values(by=['Mes Numerico'], ascending=True).reset_index(drop=True)
# Out:
#            Mes  Mes Numerico  COSTO TOTAL ARTICULO
# 0      febrero             2          3.931800e+06
# 1        marzo             3          3.059072e+06
# 2        abril             4          2.690730e+06
# 3         mayo             5          2.923141e+06
# 4        junio             6          2.701997e+06
# 5        julio             7          2.845661e+06
# 6       agosto             8          2.397034e+06
# 7   septiembre             9          3.243492e+06
# 8      octubre            10          3.095877e+06
# 9    noviembre            11          3.214950e+06
# 10   diciembre            12          3.596281e+06
# 11  enero 2022            13          4.199016e+06

# %%
top_10_costo = df_inventario_completo.groupby(['NOMPROD'])['Costo Compra'].sum().reset_index()
toptop_10_costo = top_10_costo.sort_values(by=['Costo Compra'], ascending=False).reset_index(drop=True)
top_10_costo[0:11]
# Out:
#                                           NOMPROD  Costo Compra
# 0                        ACIDRINE 10 mg * 15 TAB.  2.271346e+07
# 1                             ACIDRINE GOTAS 25ml  1.325016e+06
# 2                            ACIDRINE JBE. 100 ml  5.975382e+06
# 3                    ACIDRINE-D JBE FRASCO x 60ml  1.989856e+06
# 4                           ACTIN 120mg x 30 CAP.  6.539649e+06
# 5                  ACTIN 80mg * 10 CAPS.VEGETALES  3.625326e+06
# 6                 AEROVIAL CON INHALADOR * 30 CAP  2.412130e+08
# 7                AEROVIAL SIN INHALADOR * 30 CAPS  2.865401e+08
# 8                     AIROMED 10 MG CAJA * 30 TAB  1.780458e+07
# 9              AIROMED 4 MG GRANULADO * 30 SOBRES  1.928751e+07
# 10  AIROMED 4 MG X 30 TABS. MASTICABLES (OPA/ALU)  6.945238e+06

# %%
top_10_cantidad = df_inventario_completo.groupby(['NOMPROD'])['Costo Compra'].sum().reset_index()
top_10_cantidad = top_10_cantidad.sort_values(by=['Costo Compra'], ascending=False).reset_index(drop=True)
top_10_cantidad[0:11]
# Out:
#                                          NOMPROD  CANTIDAD ARTICULO
# 0                     CONGESTEX X 10 CAPSULAS NF       68118.600000
# 1                        GELIMED 10g * 30 SOBRES       63279.100000
# 2                 GELIMED 10g x 30 SOBRES (FCSA)       63279.100000
# 3                    GELIMED 10g * 30 SOBRES (P)       63279.100000
# 4   FERBIN JARABE 250mg/5mL x 120mL INST FCO PET       55885.000000
# 5            SUPREFLUX FORTE x 12 SACHETS x 10mL       42367.916667
# 6                     CRONOFEN L JARABE * 100 ML       27378.000000
# 7       NAPROFLASH 10 BL PAGUE 3 LLEVE 4 40 CAP.       26008.000000
# 8                      PRAZED 20mg * 30 CAPS. NF       18425.233333
# 9                         PRAZED 20mg * 30 CAPS.       18425.233333
# 10                  CRONOFEN GOTAS FCO x 30mL NR       14564.000000

# %%
total_inv = pd.read_csv(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Reporte_Merge_Inventario_Portafolio.csv')
# Out:
# C:\Users\fcoy\AppData\Local\Temp\ipykernel_12020\1388954769.py:1: DtypeWarning: Columns (8,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   total_inv = pd.read_csv(r'C:\Users\fcoy\Documents\Personal Docs\Farma\Medical_Data\Data\Reporte_Merge_Inventario_Portafolio.csv')

# %%
total_inv.columns
# Out:
# Index(['Unnamed: 0', 'FECHA', 'DIVISION', 'CODIGO ORGANIZACION',
#        'ORGANIZACION', 'Regional', 'Ciudad', 'Direccion', 'nit_proveedor',
#        'nombre_proveedor', 'ARTICULO', 'EAN', 'DESCRIPCION', 'FACTOR', 'UDM',
#        'CANTIDAD ARTICULO', 'COSTO TOTAL ARTICULO', 'Regional Correcta',
#        'Mes Numerico', 'Año', 'Mes', 'CANAL', 'COD_EAN13', 'CODPRO', 'NOMPROD',
#        'LINEA', 'MARCA'],
#       dtype='object')

# %%
regional = total_inv[total_inv['Regional'] == 'Antioquia']

# %%
ciudadl = regional[regional['Ciudad'] == 'APARTADO']

# %%
organizacion = ciudadl[ciudadl['ORGANIZACION'] == '699_CRUZ_VERDE_SR_MEDICARTE_NUEVO APARTADO']

# %%
organizacion.shape
# Out:
# (113, 27)

# %%
medicamento = organizacion[organizacion['NOMPROD'] == 'BILLOX TAB. FCO x 30 TAB']

# %%
total_inv[]
# Out:
#         Unnamed: 0                FECHA DIVISION  CODIGO ORGANIZACION  \
# 0                0  2021-01-02 06:36:54    FARMA                   27
# 1                1  2021-01-02 06:36:54    FARMA                   27
# 2                2  2021-01-02 06:36:54  CONSUMO                   27
# 3                3  2021-01-02 06:36:54    FARMA                  281
# 4                4  2021-01-02 06:36:54  CONSUMO                   20
# ...            ...                  ...      ...                  ...
# 237446      237446  2022-01-01 04:59:38    FARMA                  479
# 237447      237447  2022-01-01 04:59:38    FARMA                   48
# 237448      237448  2022-01-01 04:59:38    FARMA                  351
# 237449      237449  2022-01-01 04:59:38    FARMA                  983
# 237450      237450  2022-01-01 04:59:38    FARMA                  351
#
#                                              ORGANIZACION     Regional  \
# ...

# %%
medicamento['CANTIDAD ARTICULO']
# Out:
# 211705    1.0
# 234289    1.0
# Name: CANTIDAD ARTICULO, dtype: float64

# %%
regional_behaviour = df_filter_city_region_shop.groupby(['NOMPROD','Regional Correcta', 'Mes','Mes Numerico'])['COSTO TOTAL ARTICULO'].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [63], in <module>
# ----> 1 regional_behaviour = df_filter_city_region_shop.groupby(['NOMPROD','Regional Correcta', 'Mes','Mes Numerico'])['COSTO TOTAL ARTICULO'].sum().reset_index()
#
# NameError: name 'df_filter_city_region_shop' is not defined
